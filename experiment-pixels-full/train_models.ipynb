# %%
from train_hnn import train
from options import get_args
import sys
import matplotlib.pylab as plt

# %%
sys.argv=['']
args = get_args()

# %%
args.total_steps = 40000
args.gpu = 2
args.verbose = 1
args.max_angle = np.pi/3.

# %%
model, stats = train(args)
# Out:
# Training HNN model:
# model contains 831970 parameters
# Had a problem loading data from /home/ca15/lagrangian-nn/experiment-pixels-full/pendulum-pixels-dataset.pkl. Rebuilding dataset...
# Making a dataset of pendulum pixel observations.
# Edit 5/20/19: you may have to rewrite the `preproc` function depending on your screen size.
# 	Called reset. Max angle= 0.342
# 	Running environment...
# /home/ca15/lagrangian-nn/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# 	Called reset. Max angle= 2.308
# 	Called reset. Max angle= 0.644
# 	Called reset. Max angle= 2.467
# 	Called reset. Max angle= 0.376
# 	Running environment...
# 	Called reset. Max angle= 0.253
# 	Running environment...
# 	Called reset. Max angle= 2.909
# 	Called reset. Max angle= 0.333
# 	Running environment...
# 	Called reset. Max angle= 2.849
# 	Called reset. Max angle= 0.257
# ...

# %%
# %run train_hnn.py --gpu 2 --total_steps 40 --batch_size 200
# Out:
# model contains 831970 parameters
#  20%|█▉        | 8/41 [00:00<00:00, 72.69it/s]
# Successfully loaded data from /home/ca15/lagrangian-nn/experiment-pixels-full/pendulum-pixels-dataset.pkl
# 100%|██████████| 41/41 [00:00<00:00, 78.97it/s]
# Final train loss 9.1501e-04 +/- 1.6748e-04
# Final test loss 1.0301e-03 +/- 1.7204e-04

# %%
# %run train_symodenet.py --gpu 2 --total_steps 4000 --batch_size 200
# Out:
# model contains 925471 parameters
#   0%|          | 5/4001 [00:00<01:22, 48.48it/s]
# Successfully loaded data from /home/ca15/lagrangian-nn/experiment-pixels-full/pendulum-pixels-dataset.pkl
# 100%|██████████| 4001/4001 [01:17<00:00, 51.67it/s]
# Final train loss 2.0309e-05 +/- 1.1993e-07
# Final test loss 3.0100e-05 +/- 2.5908e-07

# %%
# %run train_lagnet.py --gpu 2 --total_steps 4000 --batch_size 200
# Out:
# model contains 831091 parameters
#   0%|          | 6/4001 [00:00<01:18, 51.02it/s]
# Successfully loaded data from /home/ca15/lagrangian-nn/experiment-pixels-full/pendulum-pixels-dataset.pkl
# 100%|██████████| 4001/4001 [01:18<00:00, 50.83it/s]
# Final train loss 3.9426e-05 +/- 5.3089e-07
# Final test loss 5.0170e-05 +/- 6.2594e-07
